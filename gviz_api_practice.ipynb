# %% [markdown]
# # Basic google chart dynamic example

# %%
import gviz_api
import os

page_template = """
<html>
  <head>
  <title>Static example</title>
    <script src="http://www.google.com/jsapi" type="text/javascript"></script>
    <script>
      google.load("visualization", "1", {packages:["table"]});
      google.setOnLoadCallback(drawTable);
      function drawTable() {
        %(jscode)s
        var jscode_table = new google.visualization.Table(document.getElementById('table_div_jscode'));
        jscode_table.draw(jscode_data, {showRowNumber: true});
        var json_table = new google.visualization.Table(document.getElementById('table_div_json'));
        var json_data = new google.visualization.DataTable(%(json)s, 0.5);
        json_table.draw(json_data, {showRowNumber: true});
      }
    </script>
  </head>
  <body>
    <H1>Table created using ToJSCode</H1>
    <div id="table_div_jscode"></div>
    <H1>Table created using ToJSon</H1>
    <div id="table_div_json"></div>
  </body>
</html>
"""


def main():
# setting directory
    chart_dir = './charts'
    filename = 'chart1.html'
    if not os.path.exists(chart_dir):
        os.mkdir(chart_dir)
    file_path = os.path.join(chart_dir, filename)

# Creating the data
    description = {"name": ("string", "Name"),
                 "salary": ("number", "Salary"),
                 "full_time": ("boolean", "Full Time Employee")}
    data = [{"name": "Mike", "salary": (10000, "$10,000"), "full_time": True},
          {"name": "Jim", "salary": (800, "$800"), "full_time": False},
          {"name": "Alice", "salary": (12500, "$12,500"), "full_time": True},
          {"name": "Bob", "salary": (7000, "$7,000"), "full_time": True}]

# Loading it into gviz_api.DataTable
    data_table = gviz_api.DataTable(description)
    data_table.LoadData(data)

# Creating a JavaScript code string
    jscode = data_table.ToJSCode("jscode_data",
                               columns_order=("name", "salary", "full_time"),
                               order_by="salary")
# Creating a JSon string
    json = data_table.ToJSon(columns_order=("name", "salary", "full_time"),
                           order_by="salary")

# Putting the JS code and JSon string into the template
    print(page_template % vars())
    with open(file_path, 'w') as file:
        file.write(page_template % vars())


if __name__ == "__main__":
    main()
# Out:
# <html>
#   <head>
#   <title>Static example</title>
#     <script src="http://www.google.com/jsapi" type="text/javascript"></script>
#     <script>
#       google.load("visualization", "1", {packages:["table"]});
#       google.setOnLoadCallback(drawTable);
#       function drawTable() {
#         var jscode_data = new google.visualization.DataTable();
# jscode_data.addColumn("string", "Name", "name");
# jscode_data.addColumn("number", "Salary", "salary");
# jscode_data.addColumn("boolean", "Full Time Employee", "full_time");
# jscode_data.addRows(4);
# jscode_data.setCell(0, 0, "Jim");
# jscode_data.setCell(0, 1, 800, "$800");
# jscode_data.setCell(0, 2, false);
# jscode_data.setCell(1, 0, "Bob");
# jscode_data.setCell(1, 1, 7000, "$7,000");
# jscode_data.setCell(1, 2, true);
# jscode_data.setCell(2, 0, "Mike");
# jscode_data.setCell(2, 1, 10000, "$10,000");
# jscode_data.setCell(2, 2, true);
# jscode_data.setCell(3, 0, "Alice");
# jscode_data.setCell(3, 1, 12500, "$12,500");
# jscode_data.setCell(3, 2, true);
#
#         var jscode_table = new google.visualization.Table(document.getElementById('table_div_jscode'));
#         jscode_table.draw(jscode_data, {showRowNumber: true});
#         var json_table = new google.visualization.Table(document.getElementById('table_div_json'));
#         var json_data = new google.visualization.DataTable({"cols":[{"id":"name","label":"Name","type":"string"},{"id":"salary","label":"Salary","type":"number"},{"id":"full_time","label":"Full Time Employee","type":"boolean"}],"rows":[{"c":[{"v":"Jim"},{"v":800,"f":"$800"},{"v":false}]},{"c":[{"v":"Bob"},{"v":7000,"f":"$7,000"},{"v":true}]},{"c":[{"v":"Mike"},{"v":10000,"f":"$10,000"},{"v":true}]},{"c":[{"v":"Alice"},{"v":12500,"f":"$12,500"},{"v":true}]}]}, 0.5);
#         json_table.draw(json_data, {showRowNumber: true});
#       }
#     </script>
#   </head>
#   <body>
#     <H1>Table created using ToJSCode</H1>
#     <div id="table_div_jscode"></div>
#     <H1>Table created using ToJSon</H1>
#     <div id="table_div_json"></div>
#   </body>
# </html>

# %% [markdown]
# # Only using javascript code for table
# # Erase json code

# %%
import gviz_api
import os

page_template = """
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
      google.charts.load('current', {'packages':['table']});
      google.charts.setOnLoadCallback(drawTable);
      
      function drawTable() {
        %(jscode)s
        var options = {showRowNumber: false}
        var jscode_table = new google.visualization.Table(document.getElementById('table_div_jscode'));
        jscode_table.draw(jscode_data, options);        
      }
    </script>
  </head>
  <body>
    <H1>Table created using ToJSCode</H1>
    <div id="table_div_jscode"></div>
  </body>
</html>
"""


def main():
# setting directory
    chart_dir = './charts'
    filename = 'chart1.html'
    if not os.path.exists(chart_dir):
        os.mkdir(chart_dir)
    file_path = os.path.join(chart_dir, filename)

# Creating the data
    description = {"name": ("string", "Name"),
                 "salary": ("number", "Salary"),
                 "full_time": ("boolean", "Full Time Employee")}
    data = [{"name": "Mike", "salary": (10000, "$10,000"), "full_time": True},
          {"name": "Jim", "salary": (800, "$800"), "full_time": False},
          {"name": "Alice", "salary": (12500, "$12,500"), "full_time": True},
          {"name": "Bob", "salary": (7000, "$7,000"), "full_time": True}]
    
# Loading it into gviz_api.DataTable
    data_table = gviz_api.DataTable(description)
    data_table.LoadData(data)
#     data.addColumn('string', 'Name');
#         data.addColumn('number', 'Salary');
#         data.addColumn('boolean', 'Full Time Employee');
#         data.addRows([
#           ['Mike',  {v: 10000, f: '$10,000'}, true],
#           ['Jim',   {v:8000,   f: '$8,000'},  false],
#           ['Alice', {v: 12500, f: '$12,500'}, true],
#           ['Bob',   {v: 7000,  f: '$7,000'},  true]
#         ]);

# Creating a JavaScript code string
    jscode = data_table.ToJSCode("jscode_data",
                               columns_order=("name", "salary", "full_time"),
                               order_by="salary")

# Putting the JS code and JSon string into the template
    print(page_template % vars())
    with open(file_path, 'w') as file:
        file.write(page_template % vars())


if __name__ == "__main__":
    main()
# Out:
# <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#       google.charts.load('current', {'packages':['table']});
#       google.charts.setOnLoadCallback(drawTable);
#
#       function drawTable() {
#         var jscode_data = new google.visualization.DataTable();
# jscode_data.addColumn("string", "Name", "name");
# jscode_data.addColumn("number", "Salary", "salary");
# jscode_data.addColumn("boolean", "Full Time Employee", "full_time");
# jscode_data.addRows(4);
# jscode_data.setCell(0, 0, "Jim");
# jscode_data.setCell(0, 1, 800, "$800");
# jscode_data.setCell(0, 2, false);
# jscode_data.setCell(1, 0, "Bob");
# jscode_data.setCell(1, 1, 7000, "$7,000");
# jscode_data.setCell(1, 2, true);
# jscode_data.setCell(2, 0, "Mike");
# jscode_data.setCell(2, 1, 10000, "$10,000");
# jscode_data.setCell(2, 2, true);
# jscode_data.setCell(3, 0, "Alice");
# jscode_data.setCell(3, 1, 12500, "$12,500");
# jscode_data.setCell(3, 2, true);
#
#         var options = {showRowNumber: false}
#         var jscode_table = new google.visualization.Table(document.getElementById('table_div_jscode'));
#         jscode_table.draw(jscode_data, options);
#       }
#     </script>
#   </head>
#   <body>
#     <H1>Table created using ToJSCode</H1>
#     <div id="table_div_jscode"></div>
#   </body>
# </html>

# %% [markdown]
# # piechart using gviz_api

# %%
import gviz_api
import os

page_template = """
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
    
      // Load the Visualization API and the corechart package.
      //google.load("visualization", "1", {packages:["corechart"]});
      google.charts.load('current', {'packages':['corechart']});
      
      
      // Set a callback to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChart);
      
      // Callback that creates and populates a data table,
      // instantiates the pie chart, passes in the data and
      // draws it.
      function drawChart() {    
        // python replacement in the python script.
        %(jscode)s
        
        // Set chart options
        var options = {title:'How Much Pizza I Ate Last Night'};
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.PieChart(document.getElementById('piechart'));
        chart.draw(jscode_data, options);
      }
    </script>
  </head>
  <body>
    <H1>Chart created using ToJSCode</H1>
    <div id="piechart" style="width: 900px; height: 500px;"></div>
  </body>
</html>
"""
# setting directory
chart_dir = './charts'
filename = 'chart2.html'
if not os.path.exists(chart_dir):
    os.mkdir(chart_dir)
file_path = os.path.join(chart_dir, filename)
    
# Creating the data
# format1
# description = [('Topping', 'string'), ('Slices', 'number')]
# data = [["Mushrooms", {3,'3'}],
#         ["Onions", {1,'1'}],
#         ["Olives",{1,'1'}],
#         ["Zucchini",{1,'1'}],
#         ["Pepperoni",{2,'2'}]]

# format2
# description = {"name": ("string", "Topping"),
#               "slices": ("number", "Slices")}
# data = [{"name": "Mushrooms", "slices": (3, "3")},
#         {"name": "Onions", "slices": (1, "1")},
#         {"name": "Olives", "slices": (1, "1")},
#         {"name": "Zucchini", "slices": (1, "1")},
#         {"name": "Pepperoni", "slices": (2, "2")}]
description = [('Event','string'), ('frequency','number')]        
data = [['Work',     11],
        ['Eat',      2],
        ['Commute',  2],
        ['Watch TV', 2],
        ['Sleep',    7]]
                  

# Loading it into gviz_api.DataTable
data_table = gviz_api.DataTable(description)
data_table.LoadData(data)

# Creating a JavaScript code string
jscode = data_table.ToJSCode("jscode_data")

# Putting the JS code and JSon string into the template
print(page_template % vars())
with open(file_path, 'w') as file:
    file.write(page_template % vars())
# Out:
# <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#
#       // Load the Visualization API and the corechart package.
#       //google.load("visualization", "1", {packages:["corechart"]});
#       google.charts.load('current', {'packages':['corechart']});
#
#
#       // Set a callback to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChart);
#
#       // Callback that creates and populates a data table,
#       // instantiates the pie chart, passes in the data and
#       // draws it.
#       function drawChart() {
#         // python replacement in the python script.
#         var jscode_data = new google.visualization.DataTable();
# jscode_data.addColumn("string", "Event", "Event");
# jscode_data.addColumn("number", "frequency", "frequency");
# jscode_data.addRows(5);
# jscode_data.setCell(0, 0, "Work");
# jscode_data.setCell(0, 1, 11);
# jscode_data.setCell(1, 0, "Eat");
# jscode_data.setCell(1, 1, 2);
# jscode_data.setCell(2, 0, "Commute");
# jscode_data.setCell(2, 1, 2);
# jscode_data.setCell(3, 0, "Watch TV");
# jscode_data.setCell(3, 1, 2);
# jscode_data.setCell(4, 0, "Sleep");
# jscode_data.setCell(4, 1, 7);
#
#
#         // Set chart options
#         var options = {title:'How Much Pizza I Ate Last Night'};
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.PieChart(document.getElementById('piechart'));
#         chart.draw(jscode_data, options);
#       }
#     </script>
#   </head>
#   <body>
#     <H1>Chart created using ToJSCode</H1>
#     <div id="piechart" style="width: 900px; height: 500px;"></div>
#   </body>
# </html>

# %%
# import pandas as pd
import numpy as np

error_table = {"type1": "disenagnement 발생",
              "type2": "stopline에서 정차못함",
              "type3": "정차된 차량을 못피함",
              "type4": "신호위반",
              "type5": "과속",
              "type6": "차선변경 못함",
              "type7": "차선유지 못함",
              "type8": "도로를 횡단하는 보행자를 못피함"}

type_index_table = dict([(i,j) for i, j in enumerate(error_table.keys())])    
prior = [0.05,0.2,0.1,0.3,0.05,0.05,0.15,0.1]
frequency_rate = np.random.choice(50,8,prior)
event_list = [i for i in error_table.values()]
event_freq_table = list(zip(event_list, frequency_rate))
event_freq_table
# Out:
# [('disenagnement 발생', 37),
#  ('stopline에서 정차못함', 46),
#  ('정차된 차량을 못피함', 29),
#  ('신호위반', 21),
#  ('과속', 21),
#  ('차선변경 못함', 26),
#  ('차선유지 못함', 17),
#  ('도로를 횡단하는 보행자를 못피함', 16)]

# %%
import gviz_api
import os
import numpy as np

page_template = """
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
    
      // Load the Visualization API and the corechart package.
      google.charts.load('current', {'packages':['corechart']});
      
      
      // Set a callback to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChart);
      
      // Callback that creates and populates a data table,
      // instantiates the pie chart, passes in the data and
      // draws it.
      function drawChart() {    
        // python replacement in the python script.
        %(jscode)s
        
        // Set chart options
        var options = {title:'Monthly issue frequenct table'};
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.PieChart(document.getElementById('piechart'));
        chart.draw(jscode_data, options);
      }
    </script>
  </head>
  <body>
    <H1>Chart created using ToJSCode</H1>
    <div id="piechart" style="width: 900px; height: 500px;"></div>
  </body>
</html>
"""
# setting directory
chart_dir = './charts'
filename = 'chart2.html'
if not os.path.exists(chart_dir):
    os.mkdir(chart_dir)
file_path = os.path.join(chart_dir, filename)
    
# Creating the data
description = [('Event','string'), ('frequency','number')]
error_table = {"type1": "disenagnement 발생",
              "type2": "stopline에서 정차못함",
              "type3": "정차된 차량을 못피함",
              "type4": "신호위반",
              "type5": "과속",
              "type6": "차선변경 못함",
              "type7": "차선유지 못함",
              "type8": "도로를 횡단하는 보행자를 못피함"}

type_index_table = dict([(i,j) for i, j in enumerate(error_table.keys())])    
prior = [0.05,0.2,0.1,0.3,0.05,0.05,0.15,0.1]
frequency_rate = [int(i) for i in np.random.choice(50,8,prior)]
event_list = [i for i in error_table.values()]
event_freq_table = list(zip(event_list, frequency_rate))

data = event_freq_table
                  

# Loading it into gviz_api.DataTable
data_table = gviz_api.DataTable(description)
data_table.LoadData(data)

# Creating a JavaScript code string
jscode = data_table.ToJSCode("jscode_data")

# Putting the JS code and JSon string into the template
print(page_template % vars())
with open(file_path, 'w') as file:
    file.write(page_template % vars())
# Out:
# <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#
#       // Load the Visualization API and the corechart package.
#       google.charts.load('current', {'packages':['corechart']});
#
#
#       // Set a callback to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChart);
#
#       // Callback that creates and populates a data table,
#       // instantiates the pie chart, passes in the data and
#       // draws it.
#       function drawChart() {
#         // python replacement in the python script.
#         var jscode_data = new google.visualization.DataTable();
# jscode_data.addColumn("string", "Event", "Event");
# jscode_data.addColumn("number", "frequency", "frequency");
# jscode_data.addRows(8);
# jscode_data.setCell(0, 0, "disenagnement 발생");
# jscode_data.setCell(0, 1, 24);
# jscode_data.setCell(1, 0, "stopline에서 정차못함");
# jscode_data.setCell(1, 1, 0);
# jscode_data.setCell(2, 0, "정차된 차량을 못피함");
# jscode_data.setCell(2, 1, 35);
# jscode_data.setCell(3, 0, "신호위반");
# jscode_data.setCell(3, 1, 11);
# jscode_data.setCell(4, 0, "과속");
# jscode_data.setCell(4, 1, 33);
# jscode_data.setCell(5, 0, "차선변경 못함");
# jscode_data.setCell(5, 1, 45);
# jscode_data.setCell(6, 0, "차선유지 못함");
# jscode_data.setCell(6, 1, 6);
# jscode_data.setCell(7, 0, "도로를 횡단하는 보행자를 못피함");
# jscode_data.setCell(7, 1, 38);
#
#
#         // Set chart options
#         var options = {title:'Monthly issue frequenct table'};
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.PieChart(document.getElementById('piechart'));
#         chart.draw(jscode_data, options);
#       }
#     </script>
#   </head>
#   <body>
#     <H1>Chart created using ToJSCode</H1>
#     <div id="piechart" style="width: 900px; height: 500px;"></div>
#   </body>
# </html>

# %% [markdown]
# # piechart and histogram

# %%
"""
piechart and histogram
"""
import gviz_api
import os

page_template = """
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
    
      // Load the Visualization API and the corechart package.
      google.charts.load('current', {'packages':['corechart']});
      
      
      // Set a callback to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChart);
      
      // Callback that creates and populates a data table,
      // instantiates the pie chart, passes in the data and
      // draws it.
      function drawChart() {    
        // python replacement in the python script.
        %(jscode)s
        
        // Set chart options
        var options = {title:'Monthly issue frequency table',
                      legend: { position: 'right' }};
        var optionsforhist = {title:'Monthly issue frequency table',
                      legend: { position: 'right' },
                      hAxis: { title: "Frequency" },
                      vAxis: { title: "Number of events" }};
                       
        // Instantiate and draw our chart, passing in some options.
        var pie_chart = new google.visualization.PieChart(document.getElementById('piechart'));
        pie_chart.draw(jscode_data, options);
        
        var hist_chart = new google.visualization.Histogram(document.getElementById('histchart'));
        hist_chart.draw(jscode_data, optionsforhist);
      }
    </script>
  </head>
  <body>    
    <div id="piechart" style="width: 900px; height: 500px;"></div>
    <div id="histchart" style="width: 900px; height: 500px;"></div>
  </body>
</html>
"""
# setting directory
chart_dir = './charts'
filename = 'chart3.html'
if not os.path.exists(chart_dir):
    os.mkdir(chart_dir)
file_path = os.path.join(chart_dir, filename)
    
# Creating the data
description = [('Event','string'), ('frequency','number')]
error_table = {"type1": "disenagnement 발생",
              "type2": "stopline에서 정차못함",
              "type3": "정차된 차량을 못피함",
              "type4": "신호위반",
              "type5": "과속",
              "type6": "차선변경 못함",
              "type7": "차선유지 못함",
              "type8": "도로를 횡단하는 보행자를 못피함"}

type_index_table = dict([(i,j) for i, j in enumerate(error_table.keys())])    
prior = [0.05,0.2,0.1,0.3,0.05,0.05,0.15,0.1]
frequency_rate = [int(i) for i in np.random.choice(100,8,prior)]
event_list = [i for i in error_table.values()]
event_freq_table = list(zip(event_list, frequency_rate))

data = event_freq_table
                  

# Loading it into gviz_api.DataTable
data_table = gviz_api.DataTable(description)
data_table.LoadData(data)

# Creating a JavaScript code string
jscode = data_table.ToJSCode("jscode_data")

# Putting the JS code and JSon string into the template
print(page_template % vars())
with open(file_path, 'w') as file:
    file.write(page_template % vars())
# Out:
# <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#
#       // Load the Visualization API and the corechart package.
#       google.charts.load('current', {'packages':['corechart']});
#
#
#       // Set a callback to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChart);
#
#       // Callback that creates and populates a data table,
#       // instantiates the pie chart, passes in the data and
#       // draws it.
#       function drawChart() {
#         // python replacement in the python script.
#         var jscode_data = new google.visualization.DataTable();
# jscode_data.addColumn("string", "Event", "Event");
# jscode_data.addColumn("number", "frequency", "frequency");
# jscode_data.addRows(8);
# jscode_data.setCell(0, 0, "disenagnement 발생");
# jscode_data.setCell(0, 1, 87);
# jscode_data.setCell(1, 0, "stopline에서 정차못함");
# jscode_data.setCell(1, 1, 1);
# jscode_data.setCell(2, 0, "정차된 차량을 못피함");
# jscode_data.setCell(2, 1, 42);
# jscode_data.setCell(3, 0, "신호위반");
# jscode_data.setCell(3, 1, 9);
# jscode_data.setCell(4, 0, "과속");
# jscode_data.setCell(4, 1, 20);
# jscode_data.setCell(5, 0, "차선변경 못함");
# jscode_data.setCell(5, 1, 22);
# jscode_data.setCell(6, 0, "차선유지 못함");
# jscode_data.setCell(6, 1, 73);
# jscode_data.setCell(7, 0, "도로를 횡단하는 보행자를 못피함");
# jscode_data.setCell(7, 1, 92);
#
#
#         // Set chart options
#         var options = {title:'Monthly issue frequency table',
#                       legend: { position: 'right' }};
#         var optionsforhist = {title:'Monthly issue frequency table',
#                       legend: { position: 'right' },
#                       hAxis: { title: "Frequency" },
#                       vAxis: { title: "Number of events" }};
#
#         // Instantiate and draw our chart, passing in some options.
#         var pie_chart = new google.visualization.PieChart(document.getElementById('piechart'));
#         pie_chart.draw(jscode_data, options);
#
#         var hist_chart = new google.visualization.Histogram(document.getElementById('histchart'));
#         hist_chart.draw(jscode_data, optionsforhist);
#       }
#     </script>
#   </head>
#   <body>
#     <div id="piechart" style="width: 900px; height: 500px;"></div>
#     <div id="histchart" style="width: 900px; height: 500px;"></div>
#   </body>
# </html>

# %% [markdown]
# # line chart

# %%
"""
line chart
"""
import gviz_api
import os

page_template = """
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
    
      // Load the Visualization API and the corechart package.
      google.charts.load('current', {'packages':['corechart']});      
      
      // Set a callback for chart by time to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChartbytime);
      
      // Set a callback for chart by mile to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChartbymile);
      
      // Callback that creates and populates a data table for chart by time,
      // instantiates the chart, passes in the data and
      // draws it.
      function drawChartbytime() {    
        // python replacement in the python script.
        %(jscodefortime)s
        
        // Set chart options
        var optionsbytime = {
          title: 'Device state by time',
          //curveType: 'function',
          legend: { position: 'right' },
          hAxis: { title: "Time" },
          vAxis: { title: "Temperature of device" }};
          
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.LineChart(document.getElementById('curve_chartbytime'));
        chart.draw(jscodefortime_data, optionsbytime);
      }
      
      // Callback that creates and populates a data table for chart by mile
      function drawChartbymile() {    
        // python replacement in the python script.
        %(jscodeformile)s
        
        // Set chart options
        var optionsbymile = {
          title: 'Device state by mile',
          curveType: 'function',
          legend: { position: 'right' },
          colors: ['#E67E22','#2ECC71'],
          hAxis: { title: "Time" },
          vAxis: { title: "Temperature of device" }};
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.LineChart(document.getElementById('curve_chartbymile'));
        chart.draw(jscodeformile_data, optionsbymile);
      }
      
    </script>
  </head>
  <body>
    <div id="curve_chartbytime" style="width: 1000px; height: 500px;"></div>
    <div id="curve_chartbymile" style="width: 1000px; height: 500px;"></div>
  </body>
</html>
"""
# setting directory
chart_dir = './charts'
filename = 'chart4.html'
if not os.path.exists(chart_dir):
    os.mkdir(chart_dir)
file_path = os.path.join(chart_dir, filename)
    
# Creating the data
descriptionfortime = [('time','number'),
               ('GPU_temp','number'),
               ('CPU_temp','number')]

GPU_list = [int(i) for i in np.random.uniform(30,70,50)]
CPU_list = [int(i) for i in np.random.uniform(30,70,50)]
time_list = list(range(50))
datafortime = list(zip(time_list, GPU_list, CPU_list))

descriptionformile = [('mile','number'),
               ('GPU_temp','number'),
               ('CPU_temp','number')]

GPU_list = [int(i) for i in np.random.uniform(30,70,50)]
CPU_list = [int(i) for i in np.random.uniform(30,70,50)]
mile_list = list(range(50))
dataformile = list(zip(mile_list, GPU_list, CPU_list))

# Loading it into gviz_api.DataTable
data_tablefortime = gviz_api.DataTable(descriptionfortime)
data_tablefortime.LoadData(datafortime)

data_tableformile = gviz_api.DataTable(descriptionformile)
data_tableformile.LoadData(dataformile)

# Creating a JavaScript code string
jscodefortime = data_tablefortime.ToJSCode("jscodefortime_data")

jscodeformile = data_tableformile.ToJSCode("jscodeformile_data")

# Putting the JS code and JSon string into the template
print(page_template % vars())
with open(file_path, 'w') as file:
    file.write(page_template % vars())
# Out:
# <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#
#       // Load the Visualization API and the corechart package.
#       google.charts.load('current', {'packages':['corechart']});
#
#       // Set a callback for chart by time to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChartbytime);
#
#       // Set a callback for chart by mile to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChartbymile);
#
#       // Callback that creates and populates a data table for chart by time,
#       // instantiates the chart, passes in the data and
#       // draws it.
#       function drawChartbytime() {
#         // python replacement in the python script.
#         var jscodefortime_data = new google.visualization.DataTable();
# jscodefortime_data.addColumn("number", "time", "time");
# jscodefortime_data.addColumn("number", "GPU_temp", "GPU_temp");
# jscodefortime_data.addColumn("number", "CPU_temp", "CPU_temp");
# jscodefortime_data.addRows(50);
# jscodefortime_data.setCell(0, 0, 0);
# jscodefortime_data.setCell(0, 1, 56);
# jscodefortime_data.setCell(0, 2, 42);
# jscodefortime_data.setCell(1, 0, 1);
# jscodefortime_data.setCell(1, 1, 38);
# jscodefortime_data.setCell(1, 2, 52);
# jscodefortime_data.setCell(2, 0, 2);
# jscodefortime_data.setCell(2, 1, 43);
# jscodefortime_data.setCell(2, 2, 38);
# jscodefortime_data.setCell(3, 0, 3);
# jscodefortime_data.setCell(3, 1, 56);
# jscodefortime_data.setCell(3, 2, 58);
# jscodefortime_data.setCell(4, 0, 4);
# jscodefortime_data.setCell(4, 1, 31);
# jscodefortime_data.setCell(4, 2, 58);
# jscodefortime_data.setCell(5, 0, 5);
# jscodefortime_data.setCell(5, 1, 32);
# jscodefortime_data.setCell(5, 2, 53);
# jscodefortime_data.setCell(6, 0, 6);
# jscodefortime_data.setCell(6, 1, 60);
# jscodefortime_data.setCell(6, 2, 38);
# jscodefortime_data.setCell(7, 0, 7);
# jscodefortime_data.setCell(7, 1, 52);
# jscodefortime_data.setCell(7, 2, 43);
# jscodefortime_data.setCell(8, 0, 8);
# jscodefortime_data.setCell(8, 1, 40);
# jscodefortime_data.setCell(8, 2, 31);
# jscodefortime_data.setCell(9, 0, 9);
# jscodefortime_data.setCell(9, 1, 32);
# jscodefortime_data.setCell(9, 2, 62);
# jscodefortime_data.setCell(10, 0, 10);
# jscodefortime_data.setCell(10, 1, 40);
# jscodefortime_data.setCell(10, 2, 68);
# jscodefortime_data.setCell(11, 0, 11);
# jscodefortime_data.setCell(11, 1, 38);
# jscodefortime_data.setCell(11, 2, 60);
# jscodefortime_data.setCell(12, 0, 12);
# jscodefortime_data.setCell(12, 1, 63);
# jscodefortime_data.setCell(12, 2, 43);
# jscodefortime_data.setCell(13, 0, 13);
# jscodefortime_data.setCell(13, 1, 57);
# jscodefortime_data.setCell(13, 2, 40);
# jscodefortime_data.setCell(14, 0, 14);
# jscodefortime_data.setCell(14, 1, 32);
# jscodefortime_data.setCell(14, 2, 67);
# jscodefortime_data.setCell(15, 0, 15);
# jscodefortime_data.setCell(15, 1, 38);
# jscodefortime_data.setCell(15, 2, 49);
# jscodefortime_data.setCell(16, 0, 16);
# jscodefortime_data.setCell(16, 1, 54);
# jscodefortime_data.setCell(16, 2, 41);
# jscodefortime_data.setCell(17, 0, 17);
# jscodefortime_data.setCell(17, 1, 38);
# jscodefortime_data.setCell(17, 2, 40);
# jscodefortime_data.setCell(18, 0, 18);
# jscodefortime_data.setCell(18, 1, 63);
# jscodefortime_data.setCell(18, 2, 40);
# jscodefortime_data.setCell(19, 0, 19);
# jscodefortime_data.setCell(19, 1, 35);
# jscodefortime_data.setCell(19, 2, 48);
# jscodefortime_data.setCell(20, 0, 20);
# jscodefortime_data.setCell(20, 1, 67);
# jscodefortime_data.setCell(20, 2, 47);
# jscodefortime_data.setCell(21, 0, 21);
# jscodefortime_data.setCell(21, 1, 60);
# jscodefortime_data.setCell(21, 2, 56);
# jscodefortime_data.setCell(22, 0, 22);
# jscodefortime_data.setCell(22, 1, 64);
# jscodefortime_data.setCell(22, 2, 53);
# jscodefortime_data.setCell(23, 0, 23);
# jscodefortime_data.setCell(23, 1, 32);
# jscodefortime_data.setCell(23, 2, 32);
# jscodefortime_data.setCell(24, 0, 24);
# jscodefortime_data.setCell(24, 1, 47);
# jscodefortime_data.setCell(24, 2, 40);
# jscodefortime_data.setCell(25, 0, 25);
# jscodefortime_data.setCell(25, 1, 58);
# jscodefortime_data.setCell(25, 2, 43);
# jscodefortime_data.setCell(26, 0, 26);
# jscodefortime_data.setCell(26, 1, 67);
# jscodefortime_data.setCell(26, 2, 31);
# jscodefortime_data.setCell(27, 0, 27);
# jscodefortime_data.setCell(27, 1, 63);
# jscodefortime_data.setCell(27, 2, 56);
# jscodefortime_data.setCell(28, 0, 28);
# jscodefortime_data.setCell(28, 1, 54);
# jscodefortime_data.setCell(28, 2, 45);
# jscodefortime_data.setCell(29, 0, 29);
# jscodefortime_data.setCell(29, 1, 68);
# jscodefortime_data.setCell(29, 2, 46);
# jscodefortime_data.setCell(30, 0, 30);
# jscodefortime_data.setCell(30, 1, 53);
# jscodefortime_data.setCell(30, 2, 47);
# jscodefortime_data.setCell(31, 0, 31);
# jscodefortime_data.setCell(31, 1, 42);
# jscodefortime_data.setCell(31, 2, 54);
# jscodefortime_data.setCell(32, 0, 32);
# jscodefortime_data.setCell(32, 1, 60);
# jscodefortime_data.setCell(32, 2, 40);
# jscodefortime_data.setCell(33, 0, 33);
# jscodefortime_data.setCell(33, 1, 37);
# jscodefortime_data.setCell(33, 2, 42);
# jscodefortime_data.setCell(34, 0, 34);
# jscodefortime_data.setCell(34, 1, 61);
# jscodefortime_data.setCell(34, 2, 50);
# jscodefortime_data.setCell(35, 0, 35);
# jscodefortime_data.setCell(35, 1, 31);
# jscodefortime_data.setCell(35, 2, 66);
# jscodefortime_data.setCell(36, 0, 36);
# jscodefortime_data.setCell(36, 1, 33);
# jscodefortime_data.setCell(36, 2, 45);
# jscodefortime_data.setCell(37, 0, 37);
# jscodefortime_data.setCell(37, 1, 62);
# jscodefortime_data.setCell(37, 2, 53);
# jscodefortime_data.setCell(38, 0, 38);
# jscodefortime_data.setCell(38, 1, 35);
# jscodefortime_data.setCell(38, 2, 39);
# jscodefortime_data.setCell(39, 0, 39);
# jscodefortime_data.setCell(39, 1, 41);
# jscodefortime_data.setCell(39, 2, 32);
# jscodefortime_data.setCell(40, 0, 40);
# jscodefortime_data.setCell(40, 1, 50);
# jscodefortime_data.setCell(40, 2, 62);
# jscodefortime_data.setCell(41, 0, 41);
# jscodefortime_data.setCell(41, 1, 34);
# jscodefortime_data.setCell(41, 2, 47);
# jscodefortime_data.setCell(42, 0, 42);
# jscodefortime_data.setCell(42, 1, 46);
# jscodefortime_data.setCell(42, 2, 30);
# jscodefortime_data.setCell(43, 0, 43);
# jscodefortime_data.setCell(43, 1, 66);
# jscodefortime_data.setCell(43, 2, 59);
# jscodefortime_data.setCell(44, 0, 44);
# jscodefortime_data.setCell(44, 1, 38);
# jscodefortime_data.setCell(44, 2, 57);
# jscodefortime_data.setCell(45, 0, 45);
# jscodefortime_data.setCell(45, 1, 35);
# jscodefortime_data.setCell(45, 2, 64);
# jscodefortime_data.setCell(46, 0, 46);
# jscodefortime_data.setCell(46, 1, 32);
# jscodefortime_data.setCell(46, 2, 41);
# jscodefortime_data.setCell(47, 0, 47);
# jscodefortime_data.setCell(47, 1, 53);
# jscodefortime_data.setCell(47, 2, 40);
# jscodefortime_data.setCell(48, 0, 48);
# jscodefortime_data.setCell(48, 1, 51);
# jscodefortime_data.setCell(48, 2, 46);
# jscodefortime_data.setCell(49, 0, 49);
# jscodefortime_data.setCell(49, 1, 55);
# jscodefortime_data.setCell(49, 2, 44);
#
#
#         // Set chart options
#         var optionsbytime = {
#           title: 'Device state by time',
#           //curveType: 'function',
#           legend: { position: 'right' },
#           hAxis: { title: "Time" },
#           vAxis: { title: "Temperature of device" }};
#
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.LineChart(document.getElementById('curve_chartbytime'));
#         chart.draw(jscodefortime_data, optionsbytime);
#       }
#
#       // Callback that creates and populates a data table for chart by mile
#       function drawChartbymile() {
#         // python replacement in the python script.
#         var jscodeformile_data = new google.visualization.DataTable();
# jscodeformile_data.addColumn("number", "mile", "mile");
# jscodeformile_data.addColumn("number", "GPU_temp", "GPU_temp");
# jscodeformile_data.addColumn("number", "CPU_temp", "CPU_temp");
# jscodeformile_data.addRows(50);
# jscodeformile_data.setCell(0, 0, 0);
# jscodeformile_data.setCell(0, 1, 55);
# jscodeformile_data.setCell(0, 2, 46);
# jscodeformile_data.setCell(1, 0, 1);
# jscodeformile_data.setCell(1, 1, 56);
# jscodeformile_data.setCell(1, 2, 35);
# jscodeformile_data.setCell(2, 0, 2);
# jscodeformile_data.setCell(2, 1, 48);
# jscodeformile_data.setCell(2, 2, 56);
# jscodeformile_data.setCell(3, 0, 3);
# jscodeformile_data.setCell(3, 1, 69);
# jscodeformile_data.setCell(3, 2, 32);
# jscodeformile_data.setCell(4, 0, 4);
# jscodeformile_data.setCell(4, 1, 32);
# jscodeformile_data.setCell(4, 2, 37);
# jscodeformile_data.setCell(5, 0, 5);
# jscodeformile_data.setCell(5, 1, 38);
# jscodeformile_data.setCell(5, 2, 30);
# jscodeformile_data.setCell(6, 0, 6);
# jscodeformile_data.setCell(6, 1, 36);
# jscodeformile_data.setCell(6, 2, 52);
# jscodeformile_data.setCell(7, 0, 7);
# jscodeformile_data.setCell(7, 1, 34);
# jscodeformile_data.setCell(7, 2, 56);
# jscodeformile_data.setCell(8, 0, 8);
# jscodeformile_data.setCell(8, 1, 35);
# jscodeformile_data.setCell(8, 2, 51);
# jscodeformile_data.setCell(9, 0, 9);
# jscodeformile_data.setCell(9, 1, 59);
# jscodeformile_data.setCell(9, 2, 61);
# jscodeformile_data.setCell(10, 0, 10);
# jscodeformile_data.setCell(10, 1, 41);
# jscodeformile_data.setCell(10, 2, 61);
# jscodeformile_data.setCell(11, 0, 11);
# jscodeformile_data.setCell(11, 1, 35);
# jscodeformile_data.setCell(11, 2, 39);
# jscodeformile_data.setCell(12, 0, 12);
# jscodeformile_data.setCell(12, 1, 54);
# jscodeformile_data.setCell(12, 2, 43);
# jscodeformile_data.setCell(13, 0, 13);
# jscodeformile_data.setCell(13, 1, 35);
# jscodeformile_data.setCell(13, 2, 42);
# jscodeformile_data.setCell(14, 0, 14);
# jscodeformile_data.setCell(14, 1, 58);
# jscodeformile_data.setCell(14, 2, 52);
# jscodeformile_data.setCell(15, 0, 15);
# jscodeformile_data.setCell(15, 1, 41);
# jscodeformile_data.setCell(15, 2, 50);
# jscodeformile_data.setCell(16, 0, 16);
# jscodeformile_data.setCell(16, 1, 33);
# jscodeformile_data.setCell(16, 2, 41);
# jscodeformile_data.setCell(17, 0, 17);
# jscodeformile_data.setCell(17, 1, 39);
# jscodeformile_data.setCell(17, 2, 55);
# jscodeformile_data.setCell(18, 0, 18);
# jscodeformile_data.setCell(18, 1, 68);
# jscodeformile_data.setCell(18, 2, 52);
# jscodeformile_data.setCell(19, 0, 19);
# jscodeformile_data.setCell(19, 1, 32);
# jscodeformile_data.setCell(19, 2, 46);
# jscodeformile_data.setCell(20, 0, 20);
# jscodeformile_data.setCell(20, 1, 47);
# jscodeformile_data.setCell(20, 2, 45);
# jscodeformile_data.setCell(21, 0, 21);
# jscodeformile_data.setCell(21, 1, 47);
# jscodeformile_data.setCell(21, 2, 30);
# jscodeformile_data.setCell(22, 0, 22);
# jscodeformile_data.setCell(22, 1, 32);
# jscodeformile_data.setCell(22, 2, 51);
# jscodeformile_data.setCell(23, 0, 23);
# jscodeformile_data.setCell(23, 1, 53);
# jscodeformile_data.setCell(23, 2, 55);
# jscodeformile_data.setCell(24, 0, 24);
# jscodeformile_data.setCell(24, 1, 54);
# jscodeformile_data.setCell(24, 2, 31);
# jscodeformile_data.setCell(25, 0, 25);
# jscodeformile_data.setCell(25, 1, 58);
# jscodeformile_data.setCell(25, 2, 46);
# jscodeformile_data.setCell(26, 0, 26);
# jscodeformile_data.setCell(26, 1, 45);
# jscodeformile_data.setCell(26, 2, 54);
# jscodeformile_data.setCell(27, 0, 27);
# jscodeformile_data.setCell(27, 1, 41);
# jscodeformile_data.setCell(27, 2, 57);
# jscodeformile_data.setCell(28, 0, 28);
# jscodeformile_data.setCell(28, 1, 31);
# jscodeformile_data.setCell(28, 2, 41);
# jscodeformile_data.setCell(29, 0, 29);
# jscodeformile_data.setCell(29, 1, 43);
# jscodeformile_data.setCell(29, 2, 49);
# jscodeformile_data.setCell(30, 0, 30);
# jscodeformile_data.setCell(30, 1, 50);
# jscodeformile_data.setCell(30, 2, 33);
# jscodeformile_data.setCell(31, 0, 31);
# jscodeformile_data.setCell(31, 1, 40);
# jscodeformile_data.setCell(31, 2, 35);
# jscodeformile_data.setCell(32, 0, 32);
# jscodeformile_data.setCell(32, 1, 51);
# jscodeformile_data.setCell(32, 2, 41);
# jscodeformile_data.setCell(33, 0, 33);
# jscodeformile_data.setCell(33, 1, 67);
# jscodeformile_data.setCell(33, 2, 46);
# jscodeformile_data.setCell(34, 0, 34);
# jscodeformile_data.setCell(34, 1, 31);
# jscodeformile_data.setCell(34, 2, 55);
# jscodeformile_data.setCell(35, 0, 35);
# jscodeformile_data.setCell(35, 1, 57);
# jscodeformile_data.setCell(35, 2, 54);
# jscodeformile_data.setCell(36, 0, 36);
# jscodeformile_data.setCell(36, 1, 63);
# jscodeformile_data.setCell(36, 2, 65);
# jscodeformile_data.setCell(37, 0, 37);
# jscodeformile_data.setCell(37, 1, 39);
# jscodeformile_data.setCell(37, 2, 60);
# jscodeformile_data.setCell(38, 0, 38);
# jscodeformile_data.setCell(38, 1, 36);
# jscodeformile_data.setCell(38, 2, 38);
# jscodeformile_data.setCell(39, 0, 39);
# jscodeformile_data.setCell(39, 1, 40);
# jscodeformile_data.setCell(39, 2, 52);
# jscodeformile_data.setCell(40, 0, 40);
# jscodeformile_data.setCell(40, 1, 53);
# jscodeformile_data.setCell(40, 2, 64);
# jscodeformile_data.setCell(41, 0, 41);
# jscodeformile_data.setCell(41, 1, 58);
# jscodeformile_data.setCell(41, 2, 33);
# jscodeformile_data.setCell(42, 0, 42);
# jscodeformile_data.setCell(42, 1, 35);
# jscodeformile_data.setCell(42, 2, 49);
# jscodeformile_data.setCell(43, 0, 43);
# jscodeformile_data.setCell(43, 1, 65);
# jscodeformile_data.setCell(43, 2, 45);
# jscodeformile_data.setCell(44, 0, 44);
# jscodeformile_data.setCell(44, 1, 50);
# jscodeformile_data.setCell(44, 2, 38);
# jscodeformile_data.setCell(45, 0, 45);
# jscodeformile_data.setCell(45, 1, 67);
# jscodeformile_data.setCell(45, 2, 55);
# jscodeformile_data.setCell(46, 0, 46);
# jscodeformile_data.setCell(46, 1, 49);
# jscodeformile_data.setCell(46, 2, 35);
# jscodeformile_data.setCell(47, 0, 47);
# jscodeformile_data.setCell(47, 1, 42);
# jscodeformile_data.setCell(47, 2, 67);
# jscodeformile_data.setCell(48, 0, 48);
# jscodeformile_data.setCell(48, 1, 51);
# jscodeformile_data.setCell(48, 2, 34);
# jscodeformile_data.setCell(49, 0, 49);
# jscodeformile_data.setCell(49, 1, 43);
# jscodeformile_data.setCell(49, 2, 60);
#
#
#         // Set chart options
#         var optionsbymile = {
#           title: 'Device state by mile',
#           curveType: 'function',
#           legend: { position: 'right' },
#           colors: ['#E67E22','#2ECC71'],
#           hAxis: { title: "Time" },
#           vAxis: { title: "Temperature of device" }};
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.LineChart(document.getElementById('curve_chartbymile'));
#         chart.draw(jscodeformile_data, optionsbymile);
#       }
#
#     </script>
#   </head>
#   <body>
#     <div id="curve_chartbytime" style="width: 1000px; height: 500px;"></div>
#     <div id="curve_chartbymile" style="width: 1000px; height: 500px;"></div>
#   </body>
# </html>

# %%
whos
# Out:
# Variable             Type             Data/Info
# -----------------------------------------------
# CPU_list             list             n=50
# GPU_list             list             n=50
# chart_dir            str              ./charts
# data                 list             n=8
# data_table           DataTable        <gviz_api.DataTable object at 0x7fead51a2ba8>
# data_tableformile    DataTable        <gviz_api.DataTable object at 0x7fead51bba20>
# data_tablefortime    DataTable        <gviz_api.DataTable object at 0x7fead51bba58>
# dataformile          list             n=50
# datafortime          list             n=50
# description          list             n=2
# descriptionformile   list             n=3
# descriptionfortime   list             n=3
# error_table          dict             n=8
# event_freq_table     list             n=8
# event_list           list             n=8
# file                 TextIOWrapper    <_io.TextIOWrapper name='<...>ode='w' encoding='UTF-8'>
# file_path            str              ./charts/chart4.html
# filename             str              chart4.html
# frequency_rate       list             n=8
# gviz_api             module           <module 'gviz_api' from '<...>te-packages/gviz_api.py'>
# jscode               str              var jscode_data = new goo<...>data.setCell(7, 1, 92);\n
# jscodeformile        str              var jscodeformile_data = <...>ata.setCell(49, 2, 60);\n
# jscodefortime        str              var jscodefortime_data = <...>ata.setCell(49, 2, 44);\n
# main                 function         <function main at 0x7feb061e8488>
# mile_list            list             n=50
# np                   module           <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# os                   module           <module 'os' from '/home/<...>ern/lib/python3.6/os.py'>
# page_template        str              \n<html>\n  <head>\n    <<...>iv>\n  </body>\n</html>\n
# prior                list             n=8
# time_list            list             n=50
# type_index_table     dict             n=8

# %% [markdown]
# # Pie & history & line chart

# %%
import gviz_api
import os
import numpy as np

page_template = """
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
    
      // Load the Visualization API and the corechart package.
      google.charts.load('current', {'packages':['corechart']});
      
      
      // Set a callback to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChart);
      // Set a callback for chart by time to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChartbytime);      
      // Set a callback for chart by mile to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChartbymile);
      
      // Callback that creates and populates a data table,
      // instantiates the pie chart, passes in the data and
      // draws it.
      function drawChart() {    
        // python replacement in the python script.
        %(jscode)s
        
        // Set chart options
        var options = {title:'Monthly issue frequency table',
                      legend: { position: 'right' }};
        var optionsforhist = {title:'Monthly issue frequency table',
                      legend: { position: 'right' },
                      hAxis: { title: "Frequency" },
                      vAxis: { title: "Number of events" }};
                       
        // Instantiate and draw our chart, passing in some options.
        var pie_chart = new google.visualization.PieChart(document.getElementById('piechart'));
        pie_chart.draw(jscode_data, options);
        
        var hist_chart = new google.visualization.Histogram(document.getElementById('histchart'));
        hist_chart.draw(jscode_data, optionsforhist);
      }
      
      function drawChartbytime() {    
        // python replacement in the python script.
        %(jscodefortime)s
        
        // Set chart options
        var optionsbytime = {
          title: 'Device state by time',
          //curveType: 'function',
          legend: { position: 'right' },
          hAxis: { title: "Time" },
          vAxis: { title: "Temperature of device" }};
          
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.LineChart(document.getElementById('curve_chartbytime'));
        chart.draw(jscodefortime_data, optionsbytime);
      }
      
      // Callback that creates and populates a data table for chart by mile
      function drawChartbymile() {    
        // python replacement in the python script.
        %(jscodeformile)s
        
        // Set chart options
        var optionsbymile = {
          title: 'Device state by mile',
          curveType: 'function',
          legend: { position: 'right' },
          colors: ['#E67E22','#2ECC71'],
          hAxis: { title: "Mile" },
          vAxis: { title: "Temperature of device" }};
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.LineChart(document.getElementById('curve_chartbymile'));
        chart.draw(jscodeformile_data, optionsbymile);
      }
      
    </script>
  </head>
  <body>
    <H1>Table created using ToJSCode for thordrive</H1>
    <div id="piechart" style="width: 900px; height: 500px;"></div>
    <div id="histchart" style="width: 900px; height: 500px;"></div>
    <div id="curve_chartbytime" style="width: 1000px; height: 500px;"></div>
    <div id="curve_chartbymile" style="width: 1000px; height: 500px;"></div>
  </body>
</html>
"""
# setting directory
chart_dir = './charts'
filename = 'chart5.html'
if not os.path.exists(chart_dir):
    os.mkdir(chart_dir)
file_path = os.path.join(chart_dir, filename)
    
# Creating the data
description = [('Event','string'), ('frequency','number')]
error_table = {"type1": "disenagnement 발생",
              "type2": "stopline에서 정차못함",
              "type3": "정차된 차량을 못피함",
              "type4": "신호위반",
              "type5": "과속",
              "type6": "차선변경 못함",
              "type7": "차선유지 못함",
              "type8": "도로를 횡단하는 보행자를 못피함"}

type_index_table = dict([(i,j) for i, j in enumerate(error_table.keys())])    
prior = [0.05,0.2,0.1,0.3,0.05,0.05,0.15,0.1]
frequency_rate = [int(i) for i in np.random.choice(100,8,prior)]
event_list = [i for i in error_table.values()]
event_freq_table = list(zip(event_list, frequency_rate))

data = event_freq_table
                  
descriptionfortime = [('time','number'),
               ('GPU_temp','number'),
               ('CPU_temp','number')]

GPU_list = [int(i) for i in np.random.uniform(30,70,50)]
CPU_list = [int(i) for i in np.random.uniform(30,70,50)]
time_list = list(range(50))
datafortime = list(zip(time_list, GPU_list, CPU_list))

descriptionformile = [('mile','number'),
               ('GPU_temp','number'),
               ('CPU_temp','number')]

GPU_list = [int(i) for i in np.random.uniform(30,70,50)]
CPU_list = [int(i) for i in np.random.uniform(30,70,50)]
mile_list = list(range(50))
dataformile = list(zip(mile_list, GPU_list, CPU_list))

# Loading it into gviz_api.DataTable
data_table = gviz_api.DataTable(description)
data_table.LoadData(data)
data_tablefortime = gviz_api.DataTable(descriptionfortime)
data_tablefortime.LoadData(datafortime)
data_tableformile = gviz_api.DataTable(descriptionformile)
data_tableformile.LoadData(dataformile)

# Creating a JavaScript code string
jscode = data_table.ToJSCode("jscode_data")
jscodefortime = data_tablefortime.ToJSCode("jscodefortime_data")
jscodeformile = data_tableformile.ToJSCode("jscodeformile_data")

# Putting the JS code and JSon string into the template
print(page_template % vars())
with open(file_path, 'w') as file:
    file.write(page_template % vars())
# Out:
# <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#
#       // Load the Visualization API and the corechart package.
#       google.charts.load('current', {'packages':['corechart']});
#
#
#       // Set a callback to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChart);
#       // Set a callback for chart by time to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChartbytime);
#       // Set a callback for chart by mile to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChartbymile);
#
#       // Callback that creates and populates a data table,
#       // instantiates the pie chart, passes in the data and
#       // draws it.
#       function drawChart() {
#         // python replacement in the python script.
#         var jscode_data = new google.visualization.DataTable();
# jscode_data.addColumn("string", "Event", "Event");
# jscode_data.addColumn("number", "frequency", "frequency");
# jscode_data.addRows(8);
# jscode_data.setCell(0, 0, "disenagnement 발생");
# jscode_data.setCell(0, 1, 82);
# jscode_data.setCell(1, 0, "stopline에서 정차못함");
# jscode_data.setCell(1, 1, 47);
# jscode_data.setCell(2, 0, "정차된 차량을 못피함");
# jscode_data.setCell(2, 1, 57);
# jscode_data.setCell(3, 0, "신호위반");
# jscode_data.setCell(3, 1, 94);
# jscode_data.setCell(4, 0, "과속");
# jscode_data.setCell(4, 1, 52);
# jscode_data.setCell(5, 0, "차선변경 못함");
# jscode_data.setCell(5, 1, 68);
# jscode_data.setCell(6, 0, "차선유지 못함");
# jscode_data.setCell(6, 1, 92);
# jscode_data.setCell(7, 0, "도로를 횡단하는 보행자를 못피함");
# jscode_data.setCell(7, 1, 86);
#
#
#         // Set chart options
#         var options = {title:'Monthly issue frequency table',
#                       legend: { position: 'right' }};
#         var optionsforhist = {title:'Monthly issue frequency table',
#                       legend: { position: 'right' },
#                       hAxis: { title: "Frequency" },
#                       vAxis: { title: "Number of events" }};
#
#         // Instantiate and draw our chart, passing in some options.
#         var pie_chart = new google.visualization.PieChart(document.getElementById('piechart'));
#         pie_chart.draw(jscode_data, options);
#
#         var hist_chart = new google.visualization.Histogram(document.getElementById('histchart'));
#         hist_chart.draw(jscode_data, optionsforhist);
#       }
#
#       function drawChartbytime() {
#         // python replacement in the python script.
#         var jscodefortime_data = new google.visualization.DataTable();
# jscodefortime_data.addColumn("number", "time", "time");
# jscodefortime_data.addColumn("number", "GPU_temp", "GPU_temp");
# jscodefortime_data.addColumn("number", "CPU_temp", "CPU_temp");
# jscodefortime_data.addRows(50);
# jscodefortime_data.setCell(0, 0, 0);
# jscodefortime_data.setCell(0, 1, 59);
# jscodefortime_data.setCell(0, 2, 62);
# jscodefortime_data.setCell(1, 0, 1);
# jscodefortime_data.setCell(1, 1, 46);
# jscodefortime_data.setCell(1, 2, 39);
# jscodefortime_data.setCell(2, 0, 2);
# jscodefortime_data.setCell(2, 1, 57);
# jscodefortime_data.setCell(2, 2, 69);
# jscodefortime_data.setCell(3, 0, 3);
# jscodefortime_data.setCell(3, 1, 54);
# jscodefortime_data.setCell(3, 2, 38);
# jscodefortime_data.setCell(4, 0, 4);
# jscodefortime_data.setCell(4, 1, 67);
# jscodefortime_data.setCell(4, 2, 64);
# jscodefortime_data.setCell(5, 0, 5);
# jscodefortime_data.setCell(5, 1, 38);
# jscodefortime_data.setCell(5, 2, 41);
# jscodefortime_data.setCell(6, 0, 6);
# jscodefortime_data.setCell(6, 1, 34);
# jscodefortime_data.setCell(6, 2, 35);
# jscodefortime_data.setCell(7, 0, 7);
# jscodefortime_data.setCell(7, 1, 38);
# jscodefortime_data.setCell(7, 2, 65);
# jscodefortime_data.setCell(8, 0, 8);
# jscodefortime_data.setCell(8, 1, 38);
# jscodefortime_data.setCell(8, 2, 45);
# jscodefortime_data.setCell(9, 0, 9);
# jscodefortime_data.setCell(9, 1, 40);
# jscodefortime_data.setCell(9, 2, 60);
# jscodefortime_data.setCell(10, 0, 10);
# jscodefortime_data.setCell(10, 1, 46);
# jscodefortime_data.setCell(10, 2, 57);
# jscodefortime_data.setCell(11, 0, 11);
# jscodefortime_data.setCell(11, 1, 49);
# jscodefortime_data.setCell(11, 2, 53);
# jscodefortime_data.setCell(12, 0, 12);
# jscodefortime_data.setCell(12, 1, 57);
# jscodefortime_data.setCell(12, 2, 65);
# jscodefortime_data.setCell(13, 0, 13);
# jscodefortime_data.setCell(13, 1, 60);
# jscodefortime_data.setCell(13, 2, 69);
# jscodefortime_data.setCell(14, 0, 14);
# jscodefortime_data.setCell(14, 1, 60);
# jscodefortime_data.setCell(14, 2, 39);
# jscodefortime_data.setCell(15, 0, 15);
# jscodefortime_data.setCell(15, 1, 32);
# jscodefortime_data.setCell(15, 2, 60);
# jscodefortime_data.setCell(16, 0, 16);
# jscodefortime_data.setCell(16, 1, 46);
# jscodefortime_data.setCell(16, 2, 46);
# jscodefortime_data.setCell(17, 0, 17);
# jscodefortime_data.setCell(17, 1, 34);
# jscodefortime_data.setCell(17, 2, 53);
# jscodefortime_data.setCell(18, 0, 18);
# jscodefortime_data.setCell(18, 1, 35);
# jscodefortime_data.setCell(18, 2, 61);
# jscodefortime_data.setCell(19, 0, 19);
# jscodefortime_data.setCell(19, 1, 63);
# jscodefortime_data.setCell(19, 2, 38);
# jscodefortime_data.setCell(20, 0, 20);
# jscodefortime_data.setCell(20, 1, 58);
# jscodefortime_data.setCell(20, 2, 39);
# jscodefortime_data.setCell(21, 0, 21);
# jscodefortime_data.setCell(21, 1, 31);
# jscodefortime_data.setCell(21, 2, 33);
# jscodefortime_data.setCell(22, 0, 22);
# jscodefortime_data.setCell(22, 1, 37);
# jscodefortime_data.setCell(22, 2, 69);
# jscodefortime_data.setCell(23, 0, 23);
# jscodefortime_data.setCell(23, 1, 40);
# jscodefortime_data.setCell(23, 2, 36);
# jscodefortime_data.setCell(24, 0, 24);
# jscodefortime_data.setCell(24, 1, 42);
# jscodefortime_data.setCell(24, 2, 52);
# jscodefortime_data.setCell(25, 0, 25);
# jscodefortime_data.setCell(25, 1, 65);
# jscodefortime_data.setCell(25, 2, 38);
# jscodefortime_data.setCell(26, 0, 26);
# jscodefortime_data.setCell(26, 1, 33);
# jscodefortime_data.setCell(26, 2, 31);
# jscodefortime_data.setCell(27, 0, 27);
# jscodefortime_data.setCell(27, 1, 31);
# jscodefortime_data.setCell(27, 2, 32);
# jscodefortime_data.setCell(28, 0, 28);
# jscodefortime_data.setCell(28, 1, 33);
# jscodefortime_data.setCell(28, 2, 50);
# jscodefortime_data.setCell(29, 0, 29);
# jscodefortime_data.setCell(29, 1, 30);
# jscodefortime_data.setCell(29, 2, 66);
# jscodefortime_data.setCell(30, 0, 30);
# jscodefortime_data.setCell(30, 1, 66);
# jscodefortime_data.setCell(30, 2, 58);
# jscodefortime_data.setCell(31, 0, 31);
# jscodefortime_data.setCell(31, 1, 50);
# jscodefortime_data.setCell(31, 2, 52);
# jscodefortime_data.setCell(32, 0, 32);
# jscodefortime_data.setCell(32, 1, 53);
# jscodefortime_data.setCell(32, 2, 59);
# jscodefortime_data.setCell(33, 0, 33);
# jscodefortime_data.setCell(33, 1, 40);
# jscodefortime_data.setCell(33, 2, 33);
# jscodefortime_data.setCell(34, 0, 34);
# jscodefortime_data.setCell(34, 1, 46);
# jscodefortime_data.setCell(34, 2, 62);
# jscodefortime_data.setCell(35, 0, 35);
# jscodefortime_data.setCell(35, 1, 50);
# jscodefortime_data.setCell(35, 2, 52);
# jscodefortime_data.setCell(36, 0, 36);
# jscodefortime_data.setCell(36, 1, 42);
# jscodefortime_data.setCell(36, 2, 51);
# jscodefortime_data.setCell(37, 0, 37);
# jscodefortime_data.setCell(37, 1, 58);
# jscodefortime_data.setCell(37, 2, 39);
# jscodefortime_data.setCell(38, 0, 38);
# jscodefortime_data.setCell(38, 1, 30);
# jscodefortime_data.setCell(38, 2, 30);
# jscodefortime_data.setCell(39, 0, 39);
# jscodefortime_data.setCell(39, 1, 43);
# jscodefortime_data.setCell(39, 2, 31);
# jscodefortime_data.setCell(40, 0, 40);
# jscodefortime_data.setCell(40, 1, 66);
# jscodefortime_data.setCell(40, 2, 47);
# jscodefortime_data.setCell(41, 0, 41);
# jscodefortime_data.setCell(41, 1, 66);
# jscodefortime_data.setCell(41, 2, 35);
# jscodefortime_data.setCell(42, 0, 42);
# jscodefortime_data.setCell(42, 1, 61);
# jscodefortime_data.setCell(42, 2, 55);
# jscodefortime_data.setCell(43, 0, 43);
# jscodefortime_data.setCell(43, 1, 36);
# jscodefortime_data.setCell(43, 2, 41);
# jscodefortime_data.setCell(44, 0, 44);
# jscodefortime_data.setCell(44, 1, 47);
# jscodefortime_data.setCell(44, 2, 37);
# jscodefortime_data.setCell(45, 0, 45);
# jscodefortime_data.setCell(45, 1, 61);
# jscodefortime_data.setCell(45, 2, 61);
# jscodefortime_data.setCell(46, 0, 46);
# jscodefortime_data.setCell(46, 1, 34);
# jscodefortime_data.setCell(46, 2, 61);
# jscodefortime_data.setCell(47, 0, 47);
# jscodefortime_data.setCell(47, 1, 59);
# jscodefortime_data.setCell(47, 2, 35);
# jscodefortime_data.setCell(48, 0, 48);
# jscodefortime_data.setCell(48, 1, 51);
# jscodefortime_data.setCell(48, 2, 30);
# jscodefortime_data.setCell(49, 0, 49);
# jscodefortime_data.setCell(49, 1, 53);
# jscodefortime_data.setCell(49, 2, 57);
#
#
#         // Set chart options
#         var optionsbytime = {
#           title: 'Device state by time',
#           //curveType: 'function',
#           legend: { position: 'right' },
#           hAxis: { title: "Time" },
#           vAxis: { title: "Temperature of device" }};
#
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.LineChart(document.getElementById('curve_chartbytime'));
#         chart.draw(jscodefortime_data, optionsbytime);
#       }
#
#       // Callback that creates and populates a data table for chart by mile
#       function drawChartbymile() {
#         // python replacement in the python script.
#         var jscodeformile_data = new google.visualization.DataTable();
# jscodeformile_data.addColumn("number", "mile", "mile");
# jscodeformile_data.addColumn("number", "GPU_temp", "GPU_temp");
# jscodeformile_data.addColumn("number", "CPU_temp", "CPU_temp");
# jscodeformile_data.addRows(50);
# jscodeformile_data.setCell(0, 0, 0);
# jscodeformile_data.setCell(0, 1, 54);
# jscodeformile_data.setCell(0, 2, 55);
# jscodeformile_data.setCell(1, 0, 1);
# jscodeformile_data.setCell(1, 1, 60);
# jscodeformile_data.setCell(1, 2, 39);
# jscodeformile_data.setCell(2, 0, 2);
# jscodeformile_data.setCell(2, 1, 66);
# jscodeformile_data.setCell(2, 2, 33);
# jscodeformile_data.setCell(3, 0, 3);
# jscodeformile_data.setCell(3, 1, 50);
# jscodeformile_data.setCell(3, 2, 51);
# jscodeformile_data.setCell(4, 0, 4);
# jscodeformile_data.setCell(4, 1, 55);
# jscodeformile_data.setCell(4, 2, 33);
# jscodeformile_data.setCell(5, 0, 5);
# jscodeformile_data.setCell(5, 1, 49);
# jscodeformile_data.setCell(5, 2, 34);
# jscodeformile_data.setCell(6, 0, 6);
# jscodeformile_data.setCell(6, 1, 50);
# jscodeformile_data.setCell(6, 2, 49);
# jscodeformile_data.setCell(7, 0, 7);
# jscodeformile_data.setCell(7, 1, 31);
# jscodeformile_data.setCell(7, 2, 46);
# jscodeformile_data.setCell(8, 0, 8);
# jscodeformile_data.setCell(8, 1, 37);
# jscodeformile_data.setCell(8, 2, 65);
# jscodeformile_data.setCell(9, 0, 9);
# jscodeformile_data.setCell(9, 1, 52);
# jscodeformile_data.setCell(9, 2, 36);
# jscodeformile_data.setCell(10, 0, 10);
# jscodeformile_data.setCell(10, 1, 40);
# jscodeformile_data.setCell(10, 2, 48);
# jscodeformile_data.setCell(11, 0, 11);
# jscodeformile_data.setCell(11, 1, 52);
# jscodeformile_data.setCell(11, 2, 45);
# jscodeformile_data.setCell(12, 0, 12);
# jscodeformile_data.setCell(12, 1, 59);
# jscodeformile_data.setCell(12, 2, 69);
# jscodeformile_data.setCell(13, 0, 13);
# jscodeformile_data.setCell(13, 1, 31);
# jscodeformile_data.setCell(13, 2, 50);
# jscodeformile_data.setCell(14, 0, 14);
# jscodeformile_data.setCell(14, 1, 30);
# jscodeformile_data.setCell(14, 2, 51);
# jscodeformile_data.setCell(15, 0, 15);
# jscodeformile_data.setCell(15, 1, 57);
# jscodeformile_data.setCell(15, 2, 40);
# jscodeformile_data.setCell(16, 0, 16);
# jscodeformile_data.setCell(16, 1, 44);
# jscodeformile_data.setCell(16, 2, 38);
# jscodeformile_data.setCell(17, 0, 17);
# jscodeformile_data.setCell(17, 1, 69);
# jscodeformile_data.setCell(17, 2, 45);
# jscodeformile_data.setCell(18, 0, 18);
# jscodeformile_data.setCell(18, 1, 61);
# jscodeformile_data.setCell(18, 2, 38);
# jscodeformile_data.setCell(19, 0, 19);
# jscodeformile_data.setCell(19, 1, 60);
# jscodeformile_data.setCell(19, 2, 45);
# jscodeformile_data.setCell(20, 0, 20);
# jscodeformile_data.setCell(20, 1, 32);
# jscodeformile_data.setCell(20, 2, 63);
# jscodeformile_data.setCell(21, 0, 21);
# jscodeformile_data.setCell(21, 1, 42);
# jscodeformile_data.setCell(21, 2, 41);
# jscodeformile_data.setCell(22, 0, 22);
# jscodeformile_data.setCell(22, 1, 48);
# jscodeformile_data.setCell(22, 2, 52);
# jscodeformile_data.setCell(23, 0, 23);
# jscodeformile_data.setCell(23, 1, 34);
# jscodeformile_data.setCell(23, 2, 33);
# jscodeformile_data.setCell(24, 0, 24);
# jscodeformile_data.setCell(24, 1, 46);
# jscodeformile_data.setCell(24, 2, 57);
# jscodeformile_data.setCell(25, 0, 25);
# jscodeformile_data.setCell(25, 1, 58);
# jscodeformile_data.setCell(25, 2, 36);
# jscodeformile_data.setCell(26, 0, 26);
# jscodeformile_data.setCell(26, 1, 59);
# jscodeformile_data.setCell(26, 2, 38);
# jscodeformile_data.setCell(27, 0, 27);
# jscodeformile_data.setCell(27, 1, 51);
# jscodeformile_data.setCell(27, 2, 32);
# jscodeformile_data.setCell(28, 0, 28);
# jscodeformile_data.setCell(28, 1, 60);
# jscodeformile_data.setCell(28, 2, 42);
# jscodeformile_data.setCell(29, 0, 29);
# jscodeformile_data.setCell(29, 1, 40);
# jscodeformile_data.setCell(29, 2, 41);
# jscodeformile_data.setCell(30, 0, 30);
# jscodeformile_data.setCell(30, 1, 45);
# jscodeformile_data.setCell(30, 2, 63);
# jscodeformile_data.setCell(31, 0, 31);
# jscodeformile_data.setCell(31, 1, 62);
# jscodeformile_data.setCell(31, 2, 69);
# jscodeformile_data.setCell(32, 0, 32);
# jscodeformile_data.setCell(32, 1, 60);
# jscodeformile_data.setCell(32, 2, 36);
# jscodeformile_data.setCell(33, 0, 33);
# jscodeformile_data.setCell(33, 1, 52);
# jscodeformile_data.setCell(33, 2, 56);
# jscodeformile_data.setCell(34, 0, 34);
# jscodeformile_data.setCell(34, 1, 48);
# jscodeformile_data.setCell(34, 2, 57);
# jscodeformile_data.setCell(35, 0, 35);
# jscodeformile_data.setCell(35, 1, 41);
# jscodeformile_data.setCell(35, 2, 36);
# jscodeformile_data.setCell(36, 0, 36);
# jscodeformile_data.setCell(36, 1, 33);
# jscodeformile_data.setCell(36, 2, 55);
# jscodeformile_data.setCell(37, 0, 37);
# jscodeformile_data.setCell(37, 1, 66);
# jscodeformile_data.setCell(37, 2, 44);
# jscodeformile_data.setCell(38, 0, 38);
# jscodeformile_data.setCell(38, 1, 55);
# jscodeformile_data.setCell(38, 2, 62);
# jscodeformile_data.setCell(39, 0, 39);
# jscodeformile_data.setCell(39, 1, 61);
# jscodeformile_data.setCell(39, 2, 44);
# jscodeformile_data.setCell(40, 0, 40);
# jscodeformile_data.setCell(40, 1, 61);
# jscodeformile_data.setCell(40, 2, 53);
# jscodeformile_data.setCell(41, 0, 41);
# jscodeformile_data.setCell(41, 1, 36);
# jscodeformile_data.setCell(41, 2, 40);
# jscodeformile_data.setCell(42, 0, 42);
# jscodeformile_data.setCell(42, 1, 40);
# jscodeformile_data.setCell(42, 2, 33);
# jscodeformile_data.setCell(43, 0, 43);
# jscodeformile_data.setCell(43, 1, 64);
# jscodeformile_data.setCell(43, 2, 63);
# jscodeformile_data.setCell(44, 0, 44);
# jscodeformile_data.setCell(44, 1, 42);
# jscodeformile_data.setCell(44, 2, 34);
# jscodeformile_data.setCell(45, 0, 45);
# jscodeformile_data.setCell(45, 1, 51);
# jscodeformile_data.setCell(45, 2, 43);
# jscodeformile_data.setCell(46, 0, 46);
# jscodeformile_data.setCell(46, 1, 67);
# jscodeformile_data.setCell(46, 2, 32);
# jscodeformile_data.setCell(47, 0, 47);
# jscodeformile_data.setCell(47, 1, 34);
# jscodeformile_data.setCell(47, 2, 57);
# jscodeformile_data.setCell(48, 0, 48);
# jscodeformile_data.setCell(48, 1, 44);
# jscodeformile_data.setCell(48, 2, 48);
# jscodeformile_data.setCell(49, 0, 49);
# jscodeformile_data.setCell(49, 1, 57);
# jscodeformile_data.setCell(49, 2, 47);
#
#
#         // Set chart options
#         var optionsbymile = {
#           title: 'Device state by mile',
#           curveType: 'function',
#           legend: { position: 'right' },
#           colors: ['#E67E22','#2ECC71'],
#           hAxis: { title: "Mile" },
#           vAxis: { title: "Temperature of device" }};
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.LineChart(document.getElementById('curve_chartbymile'));
#         chart.draw(jscodeformile_data, optionsbymile);
#       }
#
#     </script>
#   </head>
#   <body>
#     <H1>Table created using ToJSCode for thordrive</H1>
#     <div id="piechart" style="width: 900px; height: 500px;"></div>
#     <div id="histchart" style="width: 900px; height: 500px;"></div>
#     <div id="curve_chartbytime" style="width: 1000px; height: 500px;"></div>
#     <div id="curve_chartbymile" style="width: 1000px; height: 500px;"></div>
#   </body>
# </html>

# %% [markdown]
# #### line chart with vertical line marker

# %%
"""
line chart
"""
import gviz_api
import os
import numpy as np
page_template = """
<html>
  <head>
    <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
    <script type="text/javascript">
    
      // Load the Visualization API and the corechart package.
      google.charts.load('current', {'packages':['corechart']});      
      
      // Set a callback for chart by time to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChartbytime);      
      // Set a callback for chart by mile to run when the Google Visualization API is loaded.
      google.charts.setOnLoadCallback(drawChartbymile);
      
      //==================================================================================================
      // Callback that creates and populates a data table for chart by time,
      // instantiates the chart, passes in the data and
      // draws it.
      function drawChartbytime() {    
        // python replacement in the python script.
        %(jscodefortime)s
        
        var annotationRowIndex = data.getNumberOfRows() - 1;
        
        // Set chart options
        var optionsbytime = {
          annotation: {
                1: {
                    // set the style of the domain column annotations to "line"
                    style: 'line'}},
          title: 'Device state by time',
          //curveType: 'function',
          legend: { position: 'right' },
          hAxis: { title: "Time" },
          vAxis: { title: "Temperature of device" }};
          
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.LineChart(document.getElementById('curve_chartbytime'));
        var 
        chart.draw(jscodefortime_data, optionsbytime);
      }
      //===================================================================================================
      
      //===================================================================================================
      // Callback that creates and populates a data table for chart by mile
      function drawChartbymile() {    
        // python replacement in the python script.
        %(jscodeformile)s
        
        // Set chart options
        var optionsbymile = {
          title: 'Device state by mile',
          curveType: 'function',
          legend: { position: 'right' },
          colors: ['#E67E22','#2ECC71'],
          hAxis: { title: "Time" },
          vAxis: { title: "Temperature of device" }};
                       
        // Instantiate and draw our chart, passing in some options.
        var chart = new google.visualization.LineChart(document.getElementById('curve_chartbymile'));
        chart.draw(jscodeformile_data, optionsbymile);
      }
      //===================================================================================================
    </script>
  </head>
  <body>
    <div id="curve_chartbytime" style="width: 1000px; height: 500px;"></div>
    <div id="curve_chartbymile" style="width: 1000px; height: 500px;"></div>
    <div id="chart_div" style="width: 1000px; height: 500px;"></div>
  </body>
</html>
"""
# setting directory
chart_dir = './charts'
filename = 'chart4.html'
if not os.path.exists(chart_dir):
    os.mkdir(chart_dir)
file_path = os.path.join(chart_dir, filename)
    
# Creating the data
descriptionfortime = [('time','number'),
               ('GPU_temp','number'),
               ('CPU_temp','number')]

GPU_list = [int(i) for i in np.random.uniform(30,70,50)]
CPU_list = [int(i) for i in np.random.uniform(30,70,50)]
time_list = list(range(50))
datafortime = list(zip(time_list, GPU_list, CPU_list))

descriptionformile = [('mile','number'),
               ('GPU_temp','number'),
               ('CPU_temp','number')]

GPU_list = [int(i) for i in np.random.uniform(30,70,50)]
CPU_list = [int(i) for i in np.random.uniform(30,70,50)]
mile_list = list(range(50))
dataformile = list(zip(mile_list, GPU_list, CPU_list))

# Loading it into gviz_api.DataTable
data_tablefortime = gviz_api.DataTable(descriptionfortime)
data_tablefortime.LoadData(datafortime)

data_tableformile = gviz_api.DataTable(descriptionformile)
data_tableformile.LoadData(dataformile)

# Creating a JavaScript code string
jscodefortime = data_tablefortime.ToJSCode("jscodefortime_data")

jscodeformile = data_tableformile.ToJSCode("jscodeformile_data")

# Putting the JS code and JSon string into the template
print(page_template % vars())
with open(file_path, 'w') as file:
    file.write(page_template % vars())
# Out:
# <html>
#   <head>
#     <script type="text/javascript" src="https://www.gstatic.com/charts/loader.js"></script>
#     <script type="text/javascript">
#
#       // Load the Visualization API and the corechart package.
#       google.charts.load('current', {'packages':['corechart']});
#
#       // Set a callback for chart by time to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChartbytime);
#       // Set a callback for chart by mile to run when the Google Visualization API is loaded.
#       google.charts.setOnLoadCallback(drawChartbymile);
#       google.charts.setonLoadCallback(drawChart)
#
#       function drawChart() {
#         // Create and populate the data table.
#         var data = new google.visualization.DataTable();
#         data.addColumn('number', 'x');
#         // add an "annotation" role column to the domain column
#         data.addColumn({type: 'string', role: 'annotation'});
#         data.addColumn('number', 'y');
#
#         // add 100 rows of pseudorandom data
#         var y = 50;
#         for (var i = 0; i < 100; i++) {
#             y += Math.floor(Math.random() * 5) * Math.pow(-1, Math.floor(Math.random() * 2));
#             data.addRow([i, null, y]);
#         }
#         // add a blank row to the end of the DataTable to hold the annotations
#         data.addRow([null, null, null]);
#         // get the index of the row used for the annotations
#         var annotationRowIndex = data.getNumberOfRows() - 1;
#
#         var options = {
#             annotation: {
#                 1: {
#                     // set the style of the domain column annotations to "line"
#                     style: 'line'
#                 }
#             },
#             height: 400,
#             width: 600
#         };
#
#         // create the chart
#         var chart = new google.visualization.LineChart(document.getElementById('chart_div'));
#
#         // create 'ready' event listener to add mousemove event listener to the chart
#         var runOnce = google.visualization.events.addListener(chart, 'ready', function () {
#             google.visualization.events.removeListener(runOnce);
#             // create mousemove event listener in the chart's container
#             // I use jQuery, but you can use whatever works best for you
#             $('#chart_div').mousemove(function (e) {
#                 var xPos = e.pageX - container.offsetLeft;
#                 var yPos = e.pageY - container.offsetTop;
#                 var cli = chart.getChartLayoutInterface();
#                 var xBounds = cli.getBoundingBox('hAxis#0#gridline');
#                 var yBounds = cli.getBoundingBox('vAxis#0#gridline');
#
#                 // is the mouse inside the chart area?
#                 if (
#                     (xPos >= xBounds.left || xPos <= xBounds.left + xBounds.width) &&
#                     (yPos >= yBounds.top || yPos <= yBounds.top + yBounds.height)
#                 ) {
#                     // if so, draw the vertical line here
#                     // get the x-axis value at these coordinates
#                     var xVal = cli.getHAxisValue(xPos);
#                     // set the x-axis value of the annotation
#                     data.setValue(annotationRowIndex, 0, xVal);
#                     // set the value to display on the line, this could be any value you want
#                     data.setValue(annotationRowIndex, 1, xVal.toFixed(2));
#
#                     // get the data value (if any) at the line
#                     // truncating xVal to one decimal place,
#                     // since it is unlikely to find an annotation like that aligns precisely with the data
#                     var rows = data.getFilteredRows([{column: 0, value: parseFloat(xVal.toFixed(1))}]);
#                     if (rows.length) {
#                         var value = data.getValue(rows[0], 2);
#                         // do something with value
#                     }
#
#                     // draw the chart with the new annotation
#                     chart.draw(data, options);
#                 }
#             });
#         });
#
#         // draw the chart
#         chart.draw(data, options);
#       }
#       //==================================================================================================
#       // Callback that creates and populates a data table for chart by time,
#       // instantiates the chart, passes in the data and
#       // draws it.
#       function drawChartbytime() {
#         // python replacement in the python script.
#         var jscodefortime_data = new google.visualization.DataTable();
# jscodefortime_data.addColumn("number", "time", "time");
# jscodefortime_data.addColumn("number", "GPU_temp", "GPU_temp");
# jscodefortime_data.addColumn("number", "CPU_temp", "CPU_temp");
# jscodefortime_data.addRows(50);
# jscodefortime_data.setCell(0, 0, 0);
# jscodefortime_data.setCell(0, 1, 33);
# jscodefortime_data.setCell(0, 2, 37);
# jscodefortime_data.setCell(1, 0, 1);
# jscodefortime_data.setCell(1, 1, 40);
# jscodefortime_data.setCell(1, 2, 61);
# jscodefortime_data.setCell(2, 0, 2);
# jscodefortime_data.setCell(2, 1, 40);
# jscodefortime_data.setCell(2, 2, 52);
# jscodefortime_data.setCell(3, 0, 3);
# jscodefortime_data.setCell(3, 1, 46);
# jscodefortime_data.setCell(3, 2, 67);
# jscodefortime_data.setCell(4, 0, 4);
# jscodefortime_data.setCell(4, 1, 54);
# jscodefortime_data.setCell(4, 2, 53);
# jscodefortime_data.setCell(5, 0, 5);
# jscodefortime_data.setCell(5, 1, 57);
# jscodefortime_data.setCell(5, 2, 62);
# jscodefortime_data.setCell(6, 0, 6);
# jscodefortime_data.setCell(6, 1, 37);
# jscodefortime_data.setCell(6, 2, 35);
# jscodefortime_data.setCell(7, 0, 7);
# jscodefortime_data.setCell(7, 1, 58);
# jscodefortime_data.setCell(7, 2, 54);
# jscodefortime_data.setCell(8, 0, 8);
# jscodefortime_data.setCell(8, 1, 53);
# jscodefortime_data.setCell(8, 2, 55);
# jscodefortime_data.setCell(9, 0, 9);
# jscodefortime_data.setCell(9, 1, 34);
# jscodefortime_data.setCell(9, 2, 57);
# jscodefortime_data.setCell(10, 0, 10);
# jscodefortime_data.setCell(10, 1, 51);
# jscodefortime_data.setCell(10, 2, 48);
# jscodefortime_data.setCell(11, 0, 11);
# jscodefortime_data.setCell(11, 1, 34);
# jscodefortime_data.setCell(11, 2, 37);
# jscodefortime_data.setCell(12, 0, 12);
# jscodefortime_data.setCell(12, 1, 62);
# jscodefortime_data.setCell(12, 2, 35);
# jscodefortime_data.setCell(13, 0, 13);
# jscodefortime_data.setCell(13, 1, 37);
# jscodefortime_data.setCell(13, 2, 55);
# jscodefortime_data.setCell(14, 0, 14);
# jscodefortime_data.setCell(14, 1, 66);
# jscodefortime_data.setCell(14, 2, 49);
# jscodefortime_data.setCell(15, 0, 15);
# jscodefortime_data.setCell(15, 1, 46);
# jscodefortime_data.setCell(15, 2, 45);
# jscodefortime_data.setCell(16, 0, 16);
# jscodefortime_data.setCell(16, 1, 39);
# jscodefortime_data.setCell(16, 2, 44);
# jscodefortime_data.setCell(17, 0, 17);
# jscodefortime_data.setCell(17, 1, 61);
# jscodefortime_data.setCell(17, 2, 51);
# jscodefortime_data.setCell(18, 0, 18);
# jscodefortime_data.setCell(18, 1, 50);
# jscodefortime_data.setCell(18, 2, 46);
# jscodefortime_data.setCell(19, 0, 19);
# jscodefortime_data.setCell(19, 1, 63);
# jscodefortime_data.setCell(19, 2, 32);
# jscodefortime_data.setCell(20, 0, 20);
# jscodefortime_data.setCell(20, 1, 33);
# jscodefortime_data.setCell(20, 2, 61);
# jscodefortime_data.setCell(21, 0, 21);
# jscodefortime_data.setCell(21, 1, 43);
# jscodefortime_data.setCell(21, 2, 53);
# jscodefortime_data.setCell(22, 0, 22);
# jscodefortime_data.setCell(22, 1, 61);
# jscodefortime_data.setCell(22, 2, 56);
# jscodefortime_data.setCell(23, 0, 23);
# jscodefortime_data.setCell(23, 1, 50);
# jscodefortime_data.setCell(23, 2, 64);
# jscodefortime_data.setCell(24, 0, 24);
# jscodefortime_data.setCell(24, 1, 39);
# jscodefortime_data.setCell(24, 2, 68);
# jscodefortime_data.setCell(25, 0, 25);
# jscodefortime_data.setCell(25, 1, 30);
# jscodefortime_data.setCell(25, 2, 52);
# jscodefortime_data.setCell(26, 0, 26);
# jscodefortime_data.setCell(26, 1, 63);
# jscodefortime_data.setCell(26, 2, 44);
# jscodefortime_data.setCell(27, 0, 27);
# jscodefortime_data.setCell(27, 1, 40);
# jscodefortime_data.setCell(27, 2, 51);
# jscodefortime_data.setCell(28, 0, 28);
# jscodefortime_data.setCell(28, 1, 68);
# jscodefortime_data.setCell(28, 2, 33);
# jscodefortime_data.setCell(29, 0, 29);
# jscodefortime_data.setCell(29, 1, 49);
# jscodefortime_data.setCell(29, 2, 49);
# jscodefortime_data.setCell(30, 0, 30);
# jscodefortime_data.setCell(30, 1, 38);
# jscodefortime_data.setCell(30, 2, 53);
# jscodefortime_data.setCell(31, 0, 31);
# jscodefortime_data.setCell(31, 1, 46);
# jscodefortime_data.setCell(31, 2, 56);
# jscodefortime_data.setCell(32, 0, 32);
# jscodefortime_data.setCell(32, 1, 33);
# jscodefortime_data.setCell(32, 2, 45);
# jscodefortime_data.setCell(33, 0, 33);
# jscodefortime_data.setCell(33, 1, 33);
# jscodefortime_data.setCell(33, 2, 42);
# jscodefortime_data.setCell(34, 0, 34);
# jscodefortime_data.setCell(34, 1, 36);
# jscodefortime_data.setCell(34, 2, 39);
# jscodefortime_data.setCell(35, 0, 35);
# jscodefortime_data.setCell(35, 1, 46);
# jscodefortime_data.setCell(35, 2, 50);
# jscodefortime_data.setCell(36, 0, 36);
# jscodefortime_data.setCell(36, 1, 64);
# jscodefortime_data.setCell(36, 2, 58);
# jscodefortime_data.setCell(37, 0, 37);
# jscodefortime_data.setCell(37, 1, 34);
# jscodefortime_data.setCell(37, 2, 45);
# jscodefortime_data.setCell(38, 0, 38);
# jscodefortime_data.setCell(38, 1, 44);
# jscodefortime_data.setCell(38, 2, 40);
# jscodefortime_data.setCell(39, 0, 39);
# jscodefortime_data.setCell(39, 1, 67);
# jscodefortime_data.setCell(39, 2, 51);
# jscodefortime_data.setCell(40, 0, 40);
# jscodefortime_data.setCell(40, 1, 44);
# jscodefortime_data.setCell(40, 2, 47);
# jscodefortime_data.setCell(41, 0, 41);
# jscodefortime_data.setCell(41, 1, 48);
# jscodefortime_data.setCell(41, 2, 39);
# jscodefortime_data.setCell(42, 0, 42);
# jscodefortime_data.setCell(42, 1, 69);
# jscodefortime_data.setCell(42, 2, 61);
# jscodefortime_data.setCell(43, 0, 43);
# jscodefortime_data.setCell(43, 1, 46);
# jscodefortime_data.setCell(43, 2, 31);
# jscodefortime_data.setCell(44, 0, 44);
# jscodefortime_data.setCell(44, 1, 45);
# jscodefortime_data.setCell(44, 2, 36);
# jscodefortime_data.setCell(45, 0, 45);
# jscodefortime_data.setCell(45, 1, 31);
# jscodefortime_data.setCell(45, 2, 37);
# jscodefortime_data.setCell(46, 0, 46);
# jscodefortime_data.setCell(46, 1, 36);
# jscodefortime_data.setCell(46, 2, 31);
# jscodefortime_data.setCell(47, 0, 47);
# jscodefortime_data.setCell(47, 1, 57);
# jscodefortime_data.setCell(47, 2, 61);
# jscodefortime_data.setCell(48, 0, 48);
# jscodefortime_data.setCell(48, 1, 68);
# jscodefortime_data.setCell(48, 2, 61);
# jscodefortime_data.setCell(49, 0, 49);
# jscodefortime_data.setCell(49, 1, 60);
# jscodefortime_data.setCell(49, 2, 54);
#
#
#         // Set chart options
#         var optionsbytime = {
#           title: 'Device state by time',
#           //curveType: 'function',
#           legend: { position: 'right' },
#           hAxis: { title: "Time" },
#           vAxis: { title: "Temperature of device" }};
#
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.LineChart(document.getElementById('curve_chartbytime'));
#         chart.draw(jscodefortime_data, optionsbytime);
#       }
#       //===================================================================================================
#
#       //===================================================================================================
#       // Callback that creates and populates a data table for chart by mile
#       function drawChartbymile() {
#         // python replacement in the python script.
#         var jscodeformile_data = new google.visualization.DataTable();
# jscodeformile_data.addColumn("number", "mile", "mile");
# jscodeformile_data.addColumn("number", "GPU_temp", "GPU_temp");
# jscodeformile_data.addColumn("number", "CPU_temp", "CPU_temp");
# jscodeformile_data.addRows(50);
# jscodeformile_data.setCell(0, 0, 0);
# jscodeformile_data.setCell(0, 1, 64);
# jscodeformile_data.setCell(0, 2, 35);
# jscodeformile_data.setCell(1, 0, 1);
# jscodeformile_data.setCell(1, 1, 56);
# jscodeformile_data.setCell(1, 2, 46);
# jscodeformile_data.setCell(2, 0, 2);
# jscodeformile_data.setCell(2, 1, 45);
# jscodeformile_data.setCell(2, 2, 38);
# jscodeformile_data.setCell(3, 0, 3);
# jscodeformile_data.setCell(3, 1, 59);
# jscodeformile_data.setCell(3, 2, 53);
# jscodeformile_data.setCell(4, 0, 4);
# jscodeformile_data.setCell(4, 1, 32);
# jscodeformile_data.setCell(4, 2, 55);
# jscodeformile_data.setCell(5, 0, 5);
# jscodeformile_data.setCell(5, 1, 64);
# jscodeformile_data.setCell(5, 2, 68);
# jscodeformile_data.setCell(6, 0, 6);
# jscodeformile_data.setCell(6, 1, 49);
# jscodeformile_data.setCell(6, 2, 59);
# jscodeformile_data.setCell(7, 0, 7);
# jscodeformile_data.setCell(7, 1, 42);
# jscodeformile_data.setCell(7, 2, 63);
# jscodeformile_data.setCell(8, 0, 8);
# jscodeformile_data.setCell(8, 1, 37);
# jscodeformile_data.setCell(8, 2, 65);
# jscodeformile_data.setCell(9, 0, 9);
# jscodeformile_data.setCell(9, 1, 46);
# jscodeformile_data.setCell(9, 2, 37);
# jscodeformile_data.setCell(10, 0, 10);
# jscodeformile_data.setCell(10, 1, 31);
# jscodeformile_data.setCell(10, 2, 61);
# jscodeformile_data.setCell(11, 0, 11);
# jscodeformile_data.setCell(11, 1, 41);
# jscodeformile_data.setCell(11, 2, 40);
# jscodeformile_data.setCell(12, 0, 12);
# jscodeformile_data.setCell(12, 1, 59);
# jscodeformile_data.setCell(12, 2, 41);
# jscodeformile_data.setCell(13, 0, 13);
# jscodeformile_data.setCell(13, 1, 32);
# jscodeformile_data.setCell(13, 2, 44);
# jscodeformile_data.setCell(14, 0, 14);
# jscodeformile_data.setCell(14, 1, 37);
# jscodeformile_data.setCell(14, 2, 44);
# jscodeformile_data.setCell(15, 0, 15);
# jscodeformile_data.setCell(15, 1, 48);
# jscodeformile_data.setCell(15, 2, 59);
# jscodeformile_data.setCell(16, 0, 16);
# jscodeformile_data.setCell(16, 1, 66);
# jscodeformile_data.setCell(16, 2, 60);
# jscodeformile_data.setCell(17, 0, 17);
# jscodeformile_data.setCell(17, 1, 38);
# jscodeformile_data.setCell(17, 2, 59);
# jscodeformile_data.setCell(18, 0, 18);
# jscodeformile_data.setCell(18, 1, 63);
# jscodeformile_data.setCell(18, 2, 47);
# jscodeformile_data.setCell(19, 0, 19);
# jscodeformile_data.setCell(19, 1, 31);
# jscodeformile_data.setCell(19, 2, 62);
# jscodeformile_data.setCell(20, 0, 20);
# jscodeformile_data.setCell(20, 1, 59);
# jscodeformile_data.setCell(20, 2, 45);
# jscodeformile_data.setCell(21, 0, 21);
# jscodeformile_data.setCell(21, 1, 35);
# jscodeformile_data.setCell(21, 2, 66);
# jscodeformile_data.setCell(22, 0, 22);
# jscodeformile_data.setCell(22, 1, 47);
# jscodeformile_data.setCell(22, 2, 38);
# jscodeformile_data.setCell(23, 0, 23);
# jscodeformile_data.setCell(23, 1, 35);
# jscodeformile_data.setCell(23, 2, 46);
# jscodeformile_data.setCell(24, 0, 24);
# jscodeformile_data.setCell(24, 1, 49);
# jscodeformile_data.setCell(24, 2, 44);
# jscodeformile_data.setCell(25, 0, 25);
# jscodeformile_data.setCell(25, 1, 39);
# jscodeformile_data.setCell(25, 2, 49);
# jscodeformile_data.setCell(26, 0, 26);
# jscodeformile_data.setCell(26, 1, 62);
# jscodeformile_data.setCell(26, 2, 62);
# jscodeformile_data.setCell(27, 0, 27);
# jscodeformile_data.setCell(27, 1, 53);
# jscodeformile_data.setCell(27, 2, 36);
# jscodeformile_data.setCell(28, 0, 28);
# jscodeformile_data.setCell(28, 1, 37);
# jscodeformile_data.setCell(28, 2, 68);
# jscodeformile_data.setCell(29, 0, 29);
# jscodeformile_data.setCell(29, 1, 36);
# jscodeformile_data.setCell(29, 2, 53);
# jscodeformile_data.setCell(30, 0, 30);
# jscodeformile_data.setCell(30, 1, 42);
# jscodeformile_data.setCell(30, 2, 32);
# jscodeformile_data.setCell(31, 0, 31);
# jscodeformile_data.setCell(31, 1, 36);
# jscodeformile_data.setCell(31, 2, 69);
# jscodeformile_data.setCell(32, 0, 32);
# jscodeformile_data.setCell(32, 1, 35);
# jscodeformile_data.setCell(32, 2, 59);
# jscodeformile_data.setCell(33, 0, 33);
# jscodeformile_data.setCell(33, 1, 50);
# jscodeformile_data.setCell(33, 2, 68);
# jscodeformile_data.setCell(34, 0, 34);
# jscodeformile_data.setCell(34, 1, 33);
# jscodeformile_data.setCell(34, 2, 30);
# jscodeformile_data.setCell(35, 0, 35);
# jscodeformile_data.setCell(35, 1, 45);
# jscodeformile_data.setCell(35, 2, 42);
# jscodeformile_data.setCell(36, 0, 36);
# jscodeformile_data.setCell(36, 1, 56);
# jscodeformile_data.setCell(36, 2, 50);
# jscodeformile_data.setCell(37, 0, 37);
# jscodeformile_data.setCell(37, 1, 30);
# jscodeformile_data.setCell(37, 2, 49);
# jscodeformile_data.setCell(38, 0, 38);
# jscodeformile_data.setCell(38, 1, 47);
# jscodeformile_data.setCell(38, 2, 41);
# jscodeformile_data.setCell(39, 0, 39);
# jscodeformile_data.setCell(39, 1, 46);
# jscodeformile_data.setCell(39, 2, 46);
# jscodeformile_data.setCell(40, 0, 40);
# jscodeformile_data.setCell(40, 1, 39);
# jscodeformile_data.setCell(40, 2, 65);
# jscodeformile_data.setCell(41, 0, 41);
# jscodeformile_data.setCell(41, 1, 64);
# jscodeformile_data.setCell(41, 2, 46);
# jscodeformile_data.setCell(42, 0, 42);
# jscodeformile_data.setCell(42, 1, 38);
# jscodeformile_data.setCell(42, 2, 32);
# jscodeformile_data.setCell(43, 0, 43);
# jscodeformile_data.setCell(43, 1, 42);
# jscodeformile_data.setCell(43, 2, 65);
# jscodeformile_data.setCell(44, 0, 44);
# jscodeformile_data.setCell(44, 1, 43);
# jscodeformile_data.setCell(44, 2, 47);
# jscodeformile_data.setCell(45, 0, 45);
# jscodeformile_data.setCell(45, 1, 41);
# jscodeformile_data.setCell(45, 2, 49);
# jscodeformile_data.setCell(46, 0, 46);
# jscodeformile_data.setCell(46, 1, 37);
# jscodeformile_data.setCell(46, 2, 31);
# jscodeformile_data.setCell(47, 0, 47);
# jscodeformile_data.setCell(47, 1, 56);
# jscodeformile_data.setCell(47, 2, 55);
# jscodeformile_data.setCell(48, 0, 48);
# jscodeformile_data.setCell(48, 1, 57);
# jscodeformile_data.setCell(48, 2, 66);
# jscodeformile_data.setCell(49, 0, 49);
# jscodeformile_data.setCell(49, 1, 40);
# jscodeformile_data.setCell(49, 2, 51);
#
#
#         // Set chart options
#         var optionsbymile = {
#           title: 'Device state by mile',
#           curveType: 'function',
#           legend: { position: 'right' },
#           colors: ['#E67E22','#2ECC71'],
#           hAxis: { title: "Time" },
#           vAxis: { title: "Temperature of device" }};
#
#         // Instantiate and draw our chart, passing in some options.
#         var chart = new google.visualization.LineChart(document.getElementById('curve_chartbymile'));
#         chart.draw(jscodeformile_data, optionsbymile);
#       }
#       //===================================================================================================
#     </script>
#   </head>
#   <body>
#     <div id="curve_chartbytime" style="width: 1000px; height: 500px;"></div>
#     <div id="curve_chartbymile" style="width: 1000px; height: 500px;"></div>
#     <div id="chart_div" style="width: 1000px; height: 500px;"></div>
#   </body>
# </html>
